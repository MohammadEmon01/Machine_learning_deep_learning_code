# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ---

# %% [markdown]
# Read csv file

# %%
data = pd.read_csv("matches - matches.csv")

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# ---
# Drop a columns unsing drop fuction

# %%
data.drop('toss_decision',axis=1,inplace=True)

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner  result  \
# ...

# %%
data['winner']
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
data[['team1','team2','winner']]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %% [markdown]
# ----
# data_fatching using iloc

# %%
data.iloc[[0,1,2]]
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07        Gujarat Lions
#
#                          team2                  toss_winner  result  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore  normal
# 1       Rising Pune Supergiant       Rising Pune Supergiant  normal
# 2        Kolkata Knight Riders        Kolkata Knight Riders  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0           0     Sunrisers Hyderabad           35               0
# 1           0  Rising Pune Supergiant            0               7
# 2           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# ...

# %%
# iloc is used to select rows and columns by index
#this statement doing work like for loop
data.iloc[1:11:3]
# Out:
#     id  season       city        date                        team1  \
# 1    2    2017       Pune  2017-04-06               Mumbai Indians
# 4    5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 7    8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 10  11    2017    Kolkata  2017-04-13              Kings XI Punjab
#
#                      team2                  toss_winner  result  dl_applied  \
# 1   Rising Pune Supergiant       Rising Pune Supergiant  normal           0
# 4         Delhi Daredevils  Royal Challengers Bangalore  normal           0
# 7          Kings XI Punjab  Royal Challengers Bangalore  normal           0
# 10   Kolkata Knight Riders        Kolkata Knight Riders  normal           0
#
#                          winner  win_by_runs  win_by_wickets player_of_match  \
# 1        Rising Pune Supergiant            0               7       SPD Smith
# 4   Royal Challengers Bangalore           15               0       KM Jadhav
# ...

# %%
data.iloc[:,[4,5,10]]
# Out:
#                            team1                        team2  win_by_runs
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore           35
# 1                 Mumbai Indians       Rising Pune Supergiant            0
# 2                  Gujarat Lions        Kolkata Knight Riders            0
# 3         Rising Pune Supergiant              Kings XI Punjab            0
# 4    Royal Challengers Bangalore             Delhi Daredevils           15
# ..                           ...                          ...          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore            0
# 632                Gujarat Lions  Royal Challengers Bangalore            0
# 633          Sunrisers Hyderabad        Kolkata Knight Riders           22
# 634                Gujarat Lions          Sunrisers Hyderabad            0
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore            8
#
# [636 rows x 3 columns]

# %% [markdown]
# ---
# PLOTING GRAPH

# %%
#import librares
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data['city'].value_counts().head().plot(kind='pie', color='blue')
# Out:
# <Axes: ylabel='count'>

# %%
data['toss_winner'].value_counts().head().plot(kind='pie', color='blue')
# Out:
# <Axes: ylabel='count'>

# %%
data['win_by_runs'].plot(kind = 'hist',color='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
(data['team1'].value_counts()  + data['team2'].value_counts()).sort_values(ascending = False)
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
 data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner  result  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore  normal
# 1       Rising Pune Supergiant       Rising Pune Supergiant  normal
# 2        Kolkata Knight Riders        Kolkata Knight Riders  normal
# 3              Kings XI Punjab              Kings XI Punjab  normal
# 4             Delhi Daredevils  Royal Challengers Bangalore  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# 0           0          Sunrisers Hyderabad           35               0
# ...

# %%
data.sort_values(['city','date'],ascending = [True,False])
# Out:
#       id  season       city        date                        team1  \
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# ..   ...     ...        ...         ...                          ...
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 461  462    2014        NaN  2014-04-19               Mumbai Indians
# 462  463    2014        NaN  2014-04-19        Kolkata Knight Riders
#
#                            team2                  toss_winner  result  \
# ...

# %%
data.isnull().sum().sort_values(ascending = False)
# Out:
# umpire3            636
# city                 7
# winner               3
# player_of_match      3
# umpire1              1
# umpire2              1
# id                   0
# date                 0
# season               0
# dl_applied           0
# result               0
# toss_winner          0
# team2                0
# team1                0
# win_by_runs          0
# win_by_wickets       0
# venue                0
# dtype: int64

# %%
data['city'] = data['city'].ffill()

# %%
data.isnull().sum().sort_values(ascending = False)
# Out:
# umpire3            636
# player_of_match      3
# winner               3
# umpire2              1
# umpire1              1
# id                   0
# season               0
# date                 0
# city                 0
# dl_applied           0
# result               0
# toss_winner          0
# team2                0
# team1                0
# win_by_runs          0
# win_by_wickets       0
# venue                0
# dtype: int64

# %%
data.sort_values(['city','date'],ascending = [True,False]).head()
# Out:
#       id  season       city        date                        team1  \
# 476  477    2014  Abu Dhabi  2014-04-30          Sunrisers Hyderabad
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
#
#                      team2            toss_winner  result  dl_applied  \
# 476         Mumbai Indians         Mumbai Indians  normal           0
# 475  Kolkata Knight Riders       Rajasthan Royals     tie           0
# 470       Rajasthan Royals       Rajasthan Royals  normal           0
# 471  Kolkata Knight Riders  Kolkata Knight Riders  normal           0
# 464       Delhi Daredevils    Chennai Super Kings  normal           0
#
#                   winner  win_by_runs  win_by_wickets player_of_match  \
# ...

# %% [markdown]
# ---
# DROP_DUPLICATES

# %%
data.drop_duplicates(subset = ['city','season']).shape
# Out:
# (106, 17)

# %%
data.drop_duplicates(subset = ['city']).shape
# Out:
# (30, 17)

# %%
data.drop_duplicates('season',keep='last')[['season','winner']].sort_values('season')
# Out:
#      season                 winner
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 58     2017         Mumbai Indians

# %% [markdown]
# ---
# Group function

# %%
matches = data.head()

# %%
matches
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner  result  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore  normal
# 1       Rising Pune Supergiant       Rising Pune Supergiant  normal
# 2        Kolkata Knight Riders        Kolkata Knight Riders  normal
# 3              Kings XI Punjab              Kings XI Punjab  normal
# 4             Delhi Daredevils  Royal Challengers Bangalore  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# 0           0          Sunrisers Hyderabad           35               0
# ...

# %%
cityes = data.groupby('city')

# %%
len(cityes)
# Out:
# 30

# %%
cityes.size().sort_values(ascending = False)
# Out:
# city
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Ahmedabad         12
# Centurion         12
# Visakhapatnam     11
# Abu Dhabi         10
# Sharjah           10
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Port Elizabeth     7
# Ranchi             7
# Cape Town          7
# Cuttack            7
# Raipur             6
# Kochi              5
# Indore             5
# Kanpur             4
# Kimberley          3
# East London        3
# Nagpur             3
# Bloemfontein       2
# dtype: int64

# %%
cityes.first()
# Out:
#                  id  season        date                        team1  \
# city
# Abu Dhabi       458    2014  2014-04-16        Kolkata Knight Riders
# Ahmedabad       180    2010  2010-03-15             Rajasthan Royals
# Bangalore         5    2017  2017-04-08  Royal Challengers Bangalore
# Bloemfontein    161    2009  2009-05-15             Delhi Daredevils
# Cape Town       118    2009  2009-04-18               Mumbai Indians
# Centurion       133    2009  2009-04-28             Delhi Daredevils
# Chandigarh       32    2017  2017-04-28          Sunrisers Hyderabad
# Chennai          67    2008  2008-04-23          Chennai Super Kings
# Cuttack         186    2010  2010-03-19              Deccan Chargers
# Delhi            15    2017  2017-04-15             Delhi Daredevils
# Dharamsala      225    2010  2010-04-16              Kings XI Punjab
# Durban          123    2009  2009-04-21              Kings XI Punjab
# ...

# %%
cityes.groups
# Out:
# {'Abu Dhabi': [457, 459, 460, 461, 462, 464, 470, 471, 475, 476], 'Ahmedabad': [179, 186, 194, 197, 481, 486, 497, 500, 525, 532, 535, 539], 'Bangalore': [4, 11, 16, 29, 41, 44, 56, 57, 59, 69, 73, 83, 89, 103, 110, 180, 183, 191, 196, 213, 216, 225, 241, 267, 279, 282, 290, 301, 311, 316, 325, 328, 349, 355, 366, 378, 382, 391, 400, 406, 410, 428, 431, 451, 480, 487, 491, 494, 509, 516, 524, 533, 537, 545, 549, 556, 570, 579, 586, 605, 610, 616, 619, 625, 632, 635], 'Bloemfontein': [160, 164], 'Cape Town': [117, 118, 119, 120, 123, 125, 129], 'Centurion': [132, 135, 136, 146, 147, 148, 155, 156, 165, 169, 170, 171], 'Chandigarh': [31, 34, 45, 47, 60, 68, 72, 80, 93, 96, 107, 176, 192, 195, 204, 214, 242, 255, 283, 286, 320, 329, 332, 339, 353, 365, 390, 399, 408, 435, 439, 447, 504, 508, 511, 543, 551, 565, 568, 578, 585, 588, 596, 611, 614, 621], 'Chennai': [66, 70, 78, 84, 90, 106, 109, 178, 189, 201, 205, 210, 221, 223, 234, 247, 261, 271, 275, 288, 296, 305, 306, 307, 319, 331, 
# ...

# %%
data.iloc[510,:]
# Out:
# id                                   511
# season                              2014
# city                             Kolkata
# date                          2014-05-24
# team1                Sunrisers Hyderabad
# team2              Kolkata Knight Riders
# toss_winner        Kolkata Knight Riders
# result                            normal
# dl_applied                             0
# winner             Kolkata Knight Riders
# win_by_runs                            0
# win_by_wickets                         4
# player_of_match                YK Pathan
# venue                       Eden Gardens
# umpire1                     RM Deshpande
# umpire2                     BNJ Oxenford
# umpire3                              NaN
# Name: 510, dtype: object

# %%
cityes.sum()
# Out:
#                    id  season  \
# city
# Abu Dhabi        4665   20140
# Ahmedabad        4863   24156
# Bangalore       22299  132861
# Bloemfontein      326    4018
# Cape Town         858   14063
# Centurion        1842   24108
# Chandigarh      15325   92582
# Chennai         15096   96554
# Cuttack          2534   14086
# Delhi           19600  120771
# Dharamsala       2949   18103
# Durban           2147   30135
# East London       432    6027
# Hyderabad       15907   98649
# Indore            618   10073
# Jaipur           9210   66363
# Johannesburg     1279   16072
# Kanpur           1358    8066
# Kimberley         458    6027
# Kochi            1301   10055
# Kolkata         19973  122783
# Mumbai          26283  171049
# Nagpur            646    6030
# Port Elizabeth    980   14063
# Pune            11238   64455
# Raipur           3229   12088
# Rajkot           3075   20165
# Ranchi           3439   14097
# Sharjah          4685   20140
# ...
